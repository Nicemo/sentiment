# %%
import numpy as np 
import pandas as pd

# %%
exact = pd.read_csv('./data/bad_pre.csv')

# %%
for i in range(len(exact)):
    print(exact.values[i])
# Out:
# [ 'hey repeat what is it repeat talk what is it repeat an exclusive group of some wp talibans repeatwho are good at destroying selfappointed purist who gang up any one who asks them questions abt their antisocial and destructive noncontribution at wp?ask sityush to clean up his behavior than issue me nonsensical warnings repeat ']
# ['bye! dont look come or think of comming back! tosser ']
# ...

# %%
exact.values[0][0]
# Out:
# 'hey repeat what is it repeat talk what is it repeat an exclusive group of some wp talibans repeatwho are good at destroying selfappointed purist who gang up any one who asks them questions abt their antisocial and destructive noncontribution at wp?ask sityush to clean up his behavior than issue me nonsensical warnings repeat '

# %%
twitter = pd.read_csv('submission-RNN-twitter-gpu.csv')
norm = pd.read_csv('submission-RNN-pre-gpu.csv')

# %%
twitter.head()
# Out:
#                  id     toxic  severe_toxic   obscene    threat    insult  \
# 0  00001cee341fdb12  0.001027      0.000008  0.000146  0.000003  0.000165
# 1  0000247867823ef7  0.000881      0.000016  0.000119  0.000014  0.000229
# 2  00013b17ad220c46  0.021068      0.000068  0.000771  0.000043  0.002193
# 3  00017563c3f7919a  0.000866      0.000009  0.000129  0.000001  0.000195
# 4  00017695ad8997eb  0.063699      0.000227  0.001895  0.000338  0.005876
#
#    identity_hate
# 0       0.000035
# 1       0.000034
# 2       0.000282
# 3       0.000020
# 4       0.000669

# %%
norm.head()
# Out:
#                  id     toxic  severe_toxic   obscene    threat    insult  \
# 0  00001cee341fdb12  0.994358      0.552220  0.974079  0.185558  0.929511
# 1  0000247867823ef7  0.000477      0.000031  0.000263  0.000041  0.000245
# 2  00013b17ad220c46  0.010877      0.000626  0.005797  0.000337  0.001967
# 3  00017563c3f7919a  0.001064      0.000038  0.001096  0.000055  0.000828
# 4  00017695ad8997eb  0.002105      0.000089  0.002117  0.000101  0.000784
#
#    identity_hate
# 0       0.107471
# 1       0.000099
# 2       0.001569
# 3       0.000034
# 4       0.000108
